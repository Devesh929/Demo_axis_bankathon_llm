# %%
2+3+9
# Out:
# 14

# %%
import cohere
co = cohere.Client('10juIgeflFBnpaBuXf2hR6efUGbxAp08viyZbDfL')

# response = co.generate(
#   prompt='Create a software developer job description including errors in the listed technology stack and below that mentioning what could have been added more in order to make the description more impactful.',
#     model ="command",
#     max_tokens=1500
# )
# print(response)

# %%
new_prompt="generate a full professional job description of a software developer for 200 words with some discrepancies in it"

# %%
prompts = [
    "Create a software developer job description with conflicting requirements for programming languages and below that mentioning what could have been added more in order to make the description more impactful.",
    "Draft a job description for a software developer position that includes contradictory years of experience and below that mentioning what could have been added more in order to make the description more impactful.",
    "Generate a slightly flawed job description for a software developer role, listing inconsistent responsibilities and below that mentioning what could have been added more in order to make the description more impactful.",
    "Write a software developer job description with discrepancies in the required educational qualifications and below that mentioning what could have been added more in order to make the description more impactful.",
    "Devise a job description for a software developer role that includes mixed-up details about the tech stack and below that mentioning what could have been added more in order to make the description more impactful.",
    "Compose a software developer job description with contradictory information about the expected salary range and below that mentioning what could have been added more in order to make the description more impactful.",
    "Imagine a job description for a software developer position that contains inconsistencies in project deadlines and below that mentioning what could have been added more in order to make the description more impactful.",
    "Craft a job description of a software developer with minor discrepancies in the listed benefits and perks and below that mentioning what could have been added more in order to make the description more impactful.",
    "Create a software developer job description including errors in the specified years of experience and below that mentioning what could have been added more in order to make the description more impactful.",
    "Write a job description for a software developer role with conflicting information about the team structure and below that mentioning what could have been added more in order to make the description more impactful.",
    "Generate a slightly flawed job description for a software developer position, listing contradictory skills and below that mentioning what could have been added more in order to make the description more impactful.",
    "Draft a software developer job description with discrepancies in the mentioned coding standards and below that mentioning what could have been added more in order to make the description more impactful.",
    "Devise a job description for a software developer role that includes mixed-up details about the reporting hierarchy and below that mentioning what could have been added more in order to make the description more impactful.",
    "Imagine a software developer job description with contradictory information about remote work options and below that mentioning what could have been added more in order to make the description more impactful.",
    "Craft a job description of a software developer that contains inconsistencies in the required project management skills and below that mentioning what could have been added more in order to make the description more impactful.",
    "Create a software developer job description including errors in the listed professional certifications and below that mentioning what could have been added more in order to make the description more impactful.",
    "Write a job description for a software developer role with conflicting information about the company's mission and below that mentioning what could have been added more in order to make the description more impactful.",
    "Generate a slightly flawed job description for a software developer position, listing inconsistent working hours and below that mentioning what could have been added more in order to make the description more impactful.",
    "Draft a software developer job description with discrepancies in the specified benefits package and below that mentioning what could have been added more in order to make the description more impactful.",
    "Devise a job description for a software developer role that includes mixed-up details about the application domains and below that mentioning what could have been added more in order to make the description more impactful.",
    "Compose a job description of a software developer with minor discrepancies in the expected communication skills and below that mentioning what could have been added more in order to make the description more impactful.",
    "Create a software developer job description including errors in the listed technology stack and below that mentioning what could have been added more in order to make the description more impactful.",
    "Write a job description for a software developer role with conflicting information about the company's culture and below that mentioning what could have been added more in order to make the description more impactful.",
    "Generate a slightly flawed job description for a software developer position, listing contradictory reporting responsibilities and below that mentioning what could have been added more in order to make the description more impactful.",
    "Draft a software developer job description with discrepancies in the mentioned professional development opportunities and below that mentioning what could have been added more in order to make the description more impactful."
]

# %%
job_titles = [
    "Software Developer",
    "Systems Administrator",
    "Network Engineer",
    "Data Scientist",
    "DevOps Engineer",
    "Cybersecurity Analyst",
    "Cloud Architect",
    "Full Stack Developer",
    "Machine Learning Engineer",
    "Human Resources Manager",
    "Talent Acquisition Specialist",
    "Employee Relations Coordinator",
    "HR Business Partner",
    "Learning and Development Manager",
    "Marketing Manager",
    "Digital Marketing Specialist",
    "Brand Manager",
    "Content Strategist",
    "Social Media Manager",
    "Sales Executive",
    "Account Manager",
    "Business Development Manager",
    "Sales Operations Analyst",
    "Frontend Developer",
    "Backend Developer",
    "Mobile App Developer"
]
c=[]
for i in range(0,len(job_titles)):
    c.append("generate a full professional job description of a " +job_titles[i]+"for 200 words with some discrepancies in it and below that mentioning what could have been added more in order to make the description more impactful")
c
# Out:
# ['generate a full professional job description of a Software Developerfor 200 words with some discrepancies in it and below that mentioning what could have been added more in order to make the description more impactful',
#  'generate a full professional job description of a Systems Administratorfor 200 words with some discrepancies in it and below that mentioning what could have been added more in order to make the description more impactful',
#  'generate a full professional job description of a Network Engineerfor 200 words with some discrepancies in it and below that mentioning what could have been added more in order to make the description more impactful',
#  'generate a full professional job description of a Data Scientistfor 200 words with some discrepancies in it and below that mentioning what could have been added more in order to make the description more impactful',
# ...

# %%
for j in range(0,10):
    for i in range(0,len(c)):
        response = co.generate(
        prompt=c[i],model ="command",max_tokens=800)
        print("generated"+ str(i))
       
    
        # Writing the output to the file
        with open(f"./Description/Discrepancy"+job_titles[i]+"ZA1"+str(i)+str(j)+" .txt", "w") as file:
            file.write(response[0])
        print("done" + str(i) )
# Out:
# generated0
# done0
# generated1
# done1
# generated2
# done2
# generated3
# done3
# generated4
# done4
# generated5
# done5
# generated6
# done6
# generated7
# done7
# generated8
# done8
# generated9
# done9
# generated10
# done10
# generated11
# done11
# generated12
# done12
# generated13
# done13
# generated14
# done14
# generated15
# done15
# generated16
# done16
# generated17
# done17
# generated18
# done18
# generated19
# done19
# generated20
# done20
# generated21
# done21
# generated22
# done22
# generated23
# done23
# generated24
# done24
# generated25
# done25
# generated0
# done0
# generated1
# done1
# generated2
# done2
# generated3
# done3
# generated4
# done4
# generated5
# done5
# generated6
# done6
# generated7
# done7
# generated8
# done8
# generated9
# done9
# generated10
# done10
# generated11
# done11
# generated12
# done12
# generated13
# done13
# generated14
# done14
# generated15
# done15
# generated16
# done16
# generated17
# done17
# generated18
# done18
# ...
